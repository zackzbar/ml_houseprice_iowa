# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../processed_data/train_ordinal.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.min_rows', 0)
pd.set_option('display.max_rows', 1450)
data.head()
data.shape
# Out:
# (1460, 84)

# %%
num_features = data[data.applymap(np.isreal)==True].dropna(axis=1).columns.tolist()

# %%
# correlations between numerical features and SalePrice

from scipy.stats import pearsonr

df = pd.DataFrame(columns=['feature','corr'])

for x in num_features :
    value, _ = pearsonr(data[x], data['SalePrice'])
    df = df.append({'feature':x, 'corr':value}, ignore_index=True)

print('Correlation by Feature:')
display(df.sort_values(by=['corr'], ascending=False))
# Out:
# Correlation by Feature:
#                 feature      corr
# 50            SalePrice  1.000000
# 5           OverallQual  0.790982
# 23            GrLivArea  0.708624
# 10            ExterQual  0.682639
# 36           GarageCars  0.640409
# 37           GarageArea  0.623431
# 18          TotalBsmtSF  0.613581
# 20             1stFlrSF  0.605852
# 12             BsmtQual  0.585207
# 26             FullBath  0.560664
# 35         GarageFinish  0.549247
# 30         TotRmsAbvGrd  0.533723
# 51     decade_YearBuilt  0.528106
# 7             YearBuilt  0.522897
# 33          FireplaceQu  0.520438
# 34          GarageYrBlt  0.508043
# 8          YearRemodAdd  0.507101
# 53   decade_GarageYrBlt  0.502512
# 52  decade_YearRemodAdd  0.489455
# 9            MasVnrArea  0.472614
# 32           Fireplaces  0.466929
# 19            HeatingQC  0.427649
# 14           BsmtFinSF1  0.386420
# 40           WoodDeckSF  0.324413
# 21             2ndFlrSF  0.319334
# 41          OpenPorchSF  0.315856
# 13         BsmtFinType1  0.304908
# 27             HalfBath  0.284108
# 38           GarageQual  0.273839
# 3               LotArea  0.263843
# 39           GarageCond  0.263191
# 24         BsmtFullBath  0.227122
# 17            BsmtUnfSF  0.214479
# 2           LotFrontage  0.209624
# 28         BedroomAbvGr  0.168213
# 46               PoolQC  0.111696
# 44          ScreenPorch  0.111447
# 31           Functional  0.107619
# 45             PoolArea  0.092404
# 48               MoSold  0.046432
# 43            3SsnPorch  0.044584
# 11            ExterCond  0.018899
# 15         BsmtFinType2 -0.005323
# 16           BsmtFinSF2 -0.011378
# 25         BsmtHalfBath -0.016844
# 47              MiscVal -0.021190
# 0                    Id -0.021917
# 22         LowQualFinSF -0.025606
# 49               YrSold -0.028923
# 4             LandSlope -0.051152
# 6           OverallCond -0.077856
# 1            MSSubClass -0.084284
# 42        EnclosedPorch -0.128578
# 29         KitchenAbvGr -0.135907

# %%
### Observations for Upgrade Model
# Add a car to your garage for more value (attracting buyers with more cars??)
# Improve Bsmt Qual for more value (attracting families buying a long-term home?)

# %%
# TRY THIS AGAIN AFTER SOME FEATURE ENGINEERING!! SPECIFICALLY WITH OUTDOOR SPACE!

# %%
data.plot(x='OverallQual', y='SalePrice', kind='box')

# %%
sns.boxplot(x = 'OverallQual', y = 'SalePrice', data = data)

# %%
sns.scatterplot(x = 'GrLivArea', y = 'SalePrice', data = data)

# %%
data[data['GrLivArea']>4000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 523    524          60       rl          130    40094   pave  nothing
# 691    692          60       rl          104    21535   pave  nothing
# 1182  1183          60       rl          160    15623   pave  nothing
# 1298  1299          60       rl          313    63887   pave  nothing
#
#      LotShape LandContour Utilities LotConfig  LandSlope Neighborhood  \
# 523       ir1         bnk    allpub    inside          3      edwards
# 691       ir1         lvl    allpub    corner          3      noridge
# 1182      ir1         lvl    allpub    corner          3      noridge
# 1298      ir3         bnk    allpub    corner          3      edwards
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 523        posn       posn     1fam     2story           10            5
# 691        norm       norm     1fam     2story           10            6
# 1182       norm       norm     1fam     2story           10            5
# 1298      feedr       norm     1fam     2story           10            5
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 523        2007          2008       hip  compshg     cemntbd     cmentbd
# 691        1994          1995     gable  wdshngl     hdboard     hdboard
# 1182       1996          1996       hip  compshg     wd sdng     imstucc
# 1298       2008          2008       hip  clytile      stucco      stucco
#
#      MasVnrType  MasVnrArea  ExterQual  ExterCond Foundation  BsmtQual  \
# 523       stone         762          5          3      pconc         5
# 691     brkface        1170          5          3      pconc         5
# 1182    nothing           0          4          3      pconc         5
# 1298      stone         796          5          3      pconc         5
#
#      BsmtCond BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 523        ta           gd             6        2260             1
# 691        ta           gd             6        1455             1
# 1182       ta           av             6        2096             1
# 1298       ta           gd             6        5644             1
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  HeatingQC CentralAir  \
# 523            0        878         3138    gasa          5          y
# 691            0        989         2444    gasa          5          y
# 1182           0        300         2396    gasa          5          y
# 1298           0        466         6110    gasa          5          y
#
#      Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 523       sbrkr      3138      1538             0       4676             1
# 691       sbrkr      2444      1872             0       4316             0
# 1182      sbrkr      2411      2065             0       4476             1
# 1298      sbrkr      4692       950             0       5642             2
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 523              0         3         1             3             1
# 691              1         3         1             4             1
# 1182             0         3         1             4             1
# 1298             0         2         1             3             1
#
#      KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  \
# 523           ex            11           8           1            4
# 691           ex            10           8           2            5
# 1182          ex            10           8           2            3
# 1298          ex            12           8           3            4
#
#      GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 523     builtin         2007             3           3         884
# 691      attchd         1994             3           3         832
# 1182     attchd         1996             3           3         813
# 1298     attchd         2008             3           2        1418
#
#       GarageQual  GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 523            3           3          y         208          406
# 691            3           3          y         382           50
# 1182           3           3          y         171           78
# 1298           3           3          y         214          292
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC    Fence  \
# 523               0          0            0         0       0  nothing
# 691               0          0            0         0       0  nothing
# 1182              0          0            0       555       5    mnprv
# 1298              0          0            0       480       4  nothing
#
#      MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  \
# 523      nothing        0      10    2007      new       partial     184750
# 691      nothing        0       1    2007       wd        normal     755000
# 1182     nothing        0       7    2007       wd       abnorml     745000
# 1298     nothing        0       1    2008      new       partial     160000
#
#       decade_YearBuilt  decade_YearRemodAdd  decade_GarageYrBlt
# 523                 10                   10                  10
# 691                  9                    9                   9
# 1182                 9                    9                   9
# 1298                10                   10                  10

# %%
# Actual ID field (not index) = 524 and 1299
# OUTLIERS!! Big, high quality houses built in iffy neighborhood. Sold for partial condition.
# Late 2007, Early 2008

# %%
data_no_outlier = data.drop(data[(data['GrLivArea']>4000) & (data['SalePrice']<300000)].index)
data_no_outlier.shape
# Out:
# (1458, 84)

# %%
df = pd.DataFrame(columns=['feature','corr'])

for x in num_features :
    value, _ = pearsonr(data_no_outlier[x], data_no_outlier['SalePrice'])
    df = df.append({'feature':x, 'corr':value}, ignore_index=True)

print('Correlation by Feature:')
display(df.sort_values(by=['corr'], ascending=False))
# Out:
# Correlation by Feature:
#                 feature      corr
# 50            SalePrice  1.000000
# 5           OverallQual  0.795774
# 23            GrLivArea  0.734968
# 10            ExterQual  0.686756
# 18          TotalBsmtSF  0.651153
# 36           GarageCars  0.641047
# 20             1stFlrSF  0.631530
# 37           GarageArea  0.629217
# 12             BsmtQual  0.586674
# 26             FullBath  0.562165
# 35         GarageFinish  0.550255
# 30         TotRmsAbvGrd  0.537769
# 51     decade_YearBuilt  0.528762
# 7             YearBuilt  0.523608
# 33          FireplaceQu  0.521144
# 34          GarageYrBlt  0.508719
# 8          YearRemodAdd  0.507717
# 53   decade_GarageYrBlt  0.503102
# 52  decade_YearRemodAdd  0.489942
# 9            MasVnrArea  0.477810
# 32           Fireplaces  0.469862
# 19            HeatingQC  0.428024
# 14           BsmtFinSF1  0.409384
# 40           WoodDeckSF  0.324758
# 41          OpenPorchSF  0.321142
# 21             2ndFlrSF  0.320532
# 13         BsmtFinType1  0.305372
# 27             HalfBath  0.284590
# 38           GarageQual  0.273898
# 3               LotArea  0.268179
# 39           GarageCond  0.263249
# 24         BsmtFullBath  0.228459
# 2           LotFrontage  0.215265
# 17            BsmtUnfSF  0.214460
# 28         BedroomAbvGr  0.168245
# 46               PoolQC  0.124084
# 44          ScreenPorch  0.111415
# 31           Functional  0.107661
# 45             PoolArea  0.099490
# 48               MoSold  0.046124
# 43            3SsnPorch  0.044568
# 11            ExterCond  0.018865
# 15         BsmtFinType2 -0.005364
# 16           BsmtFinSF2 -0.011422
# 25         BsmtHalfBath -0.016881
# 47              MiscVal -0.021203
# 0                    Id -0.021673
# 22         LowQualFinSF -0.025625
# 49               YrSold -0.028882
# 4             LandSlope -0.051122
# 6           OverallCond -0.077948
# 1            MSSubClass -0.084276
# 42        EnclosedPorch -0.128646
# 29         KitchenAbvGr -0.135946

# %%
edwards = data[data['Neighborhood']=='edwards']

# %%
edwards.plot(x='OverallQual', y='SalePrice', kind='scatter')

# %%
edwards.sort_values('OverallQual', ascending=False)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 523    524          60       rl          130    40094   pave  nothing
# 1298  1299          60       rl          313    63887   pave  nothing
# 724    725          20       rl           86    13286   pave  nothing
# 362    363          85       rl           64     7301   pave  nothing
# 193    194         160       rm           24     2522   pave  nothing
# 1254  1255          60       rl           60     6931   pave  nothing
# 1088  1089         160       rm           24     2522   pave  nothing
# 1304  1305         160       rm           32     3363   pave  nothing
# 387    388          80       rl           72     7200   pave  nothing
# 1168  1169          70       rl          120    13728   pave  nothing
# 772    773          80       rl           94     7819   pave  nothing
# 563    564          50       rl           66    21780   pave  nothing
# 439    440          50       rl           67    12354   pave     grvl
# 445    446          20       rl           73     9855   pave  nothing
# 472    473         180       rm           35     3675   pave  nothing
# 1073  1074          60       rl           75     7950   pave  nothing
# 954    955          90       rl           35     9400   pave  nothing
# 647    648          20       rl           85    10452   pave  nothing
# 1273  1274          80       rl          124    11512   pave  nothing
# 582    583          90       rl           81    11841   grvl  nothing
# 110    111          50       rl           75     9525   pave  nothing
# 1297  1298         180       rm           35     3675   pave  nothing
# 269    270          20       rl            0     7917   pave  nothing
# 239    240          50       rl           52     8741   pave  nothing
# 211    212          20       rl           83    10420   pave  nothing
# 671    672          70       rh           54     6629   pave  nothing
# 175    176          20       rl           84    12615   pave  nothing
# 1384  1385          50       rl           60     9060   pave  nothing
# 155    156          50       rl           60     9600   pave  nothing
# 145    146         160       rm           24     2522   pave  nothing
# 1423  1424          80       rl            0    19690   pave  nothing
# 985    986         190       rl           68    10880   pave  nothing
# 814    815          50       rl           45     8248   pave     grvl
# 839    840          50       rl           70    11767   pave  nothing
# 880    881          20       rl           60     7024   pave  nothing
# 887    888          50       rl           59    16466   pave  nothing
# 921    922          90       rl           67     8777   pave  nothing
# 738    739          90       rl           60    10800   pave  nothing
# 1011  1012          90       rl           75     9825   pave  nothing
# 1053  1054          20       rl           68     8562   pave  nothing
# 1072  1073          50       rl           50     7585   pave  nothing
# 1123  1124          20       rl           50     9405   pave  nothing
# 1151  1152          20       rl          134    17755   pave  nothing
# 1185  1186          50       rl           60     9738   pave  nothing
# 1257  1258          30       rl           56     4060   pave  nothing
# 1294  1295          20       rl           60     8172   pave  nothing
# 1377  1378          50       rl           60    10998   pave     grvl
# 1452  1453         180       rm           35     3675   pave  nothing
# 1179  1180          20       rl           77     8335   pave  nothing
# 1459  1460          20       rl           75     9937   pave  nothing
# 607    608          20       rl           78     7800   pave  nothing
# 418    419          50       rl           60     8160   pave  nothing
# 395    396          20       rl           68     9571   pave  nothing
# 390    391          50       rl           50     8405   pave     grvl
# 502    503          20       rl           70     9170   pave  nothing
# 535    536         190       rl           70     7000   pave  nothing
# 386    387          50       rl           58     8410   pave  nothing
# 352    353          50       rl           60     9084   pave  nothing
# 292    293          50       rl           60    11409   pave  nothing
# 210    211          30       rl           67     5604   pave  nothing
# 562    563          30       rl           63    13907   pave  nothing
# 410    411          20       rl           68     9571   pave  nothing
# 638    639          30       rl           67     8777   pave  nothing
# 182    183          20       rl           60     9060   pave  nothing
# 165    166         190       rl           62    10106   pave  nothing
# 659    660          20       rl           75     9937   pave  nothing
# 117    118          20       rl           74     8536   pave  nothing
# 697    698          20       rl           57     6420   pave  nothing
# 98      99          30       rl           85    10625   pave  nothing
# 1314  1315          20       rl           60     8190   pave  nothing
# 1319  1320          20       rl           75    10215   pave  nothing
# 200    201          20       rm           80     8546   pave  nothing
# 1332  1333          20       rl           67     8877   pave  nothing
# 308    309          30       rl            0    12342   pave  nothing
# 1212  1213          30       rl           50     9340   pave  nothing
# 1448  1449          50       rl           70    11767   pave  nothing
# 97      98          20       rl           73    10921   pave  nothing
# 441    442          90       rl           92    12108   pave  nothing
# 1144  1145         190       rl           60    12180   pave  nothing
# 1020  1021          20       rl           60     7024   pave  nothing
# 771    772          20       rl           67     8877   pave  nothing
# 723    724          50       rl           60     8172   pave  nothing
# 663    664          85       rl           90    10012   pave  nothing
# 651    652          70       rl           60     9084   pave  nothing
# 917    918          20       rl            0    17140   pave  nothing
# 942    943          90       rl           42     7711   pave  nothing
# 749    750          50       rl           50     8405   pave  nothing
# 978    979          20       rl           68     9450   pave  nothing
# 1035  1036          20       rl            0    11500   pave  nothing
# 1049  1050          20       rl           60    11100   pave  nothing
# 553    554          20       rl           67     8777   pave  nothing
# 528    529          30       rl           58     9098   pave  nothing
# 1122  1123          20       rl            0     8926   pave  nothing
# 39      40          90       rl           65     6040   pave  nothing
# 1000  1001          20       rl           74    10206   pave  nothing
# 620    621          30       rl           45     8248   pave     grvl
# 1326  1327          30       rh           70     4270   pave  nothing
# 1045  1046          20       rl            0    13680   pave  nothing
# 1380  1381          30       rl           45     8212   pave     grvl
# 375    376          30       rl            0    10020   pave  nothing
#
#      LotShape LandContour Utilities LotConfig  LandSlope Neighborhood  \
# 523       ir1         bnk    allpub    inside          3      edwards
# 1298      ir3         bnk    allpub    corner          3      edwards
# 724       ir1         lvl    allpub    inside          3      edwards
# 362       reg         lvl    allpub    corner          3      edwards
# 193       reg         lvl    allpub    inside          3      edwards
# 1254      reg         lvl    allpub    inside          3      edwards
# 1088      reg         lvl    allpub    inside          3      edwards
# 1304      reg         lvl    allpub    inside          3      edwards
# 387       reg         lvl    allpub    inside          3      edwards
# 1168      reg         lvl    allpub    corner          3      edwards
# 772       reg         lvl    allpub    inside          3      edwards
# 563       reg         lvl    allpub    inside          3      edwards
# 439       reg         lvl    allpub    corner          3      edwards
# 445       reg         lvl    allpub    corner          3      edwards
# 472       reg         lvl    allpub    inside          3      edwards
# 1073      ir1         bnk    allpub    corner          3      edwards
# 954       ir1         lvl    allpub   culdsac          3      edwards
# 647       ir1         lvl    allpub    inside          3      edwards
# 1273      ir1         lvl    allpub    corner          3      edwards
# 582       reg         lvl    allpub    inside          3      edwards
# 110       reg         lvl    allpub    inside          3      edwards
# 1297      reg         lvl    allpub    inside          3      edwards
# 269       ir1         lvl    allpub    corner          3      edwards
# 239       reg         lvl    allpub    inside          3      edwards
# 211       reg         lvl    allpub    corner          3      edwards
# 671       reg         lvl    allpub    inside          3      edwards
# 175       reg         lvl    allpub    corner          3      edwards
# 1384      reg         lvl    allpub    inside          3      edwards
# 155       reg         lvl    allpub    corner          3      edwards
# 145       reg         lvl    allpub    inside          3      edwards
# 1423      ir1         lvl    allpub   culdsac          3      edwards
# 985       reg         lvl    allpub    inside          3      edwards
# 814       reg         lvl    allpub    inside          3      edwards
# 839       reg         lvl    allpub    inside          3      edwards
# 880       reg         lvl    allpub    inside          3      edwards
# 887       ir1         lvl    allpub    inside          3      edwards
# 921       reg         lvl    allpub    inside          3      edwards
# 738       reg         lvl    allpub    inside          3      edwards
# 1011      reg         lvl    allpub    inside          3      edwards
# 1053      reg         lvl    allpub    inside          2      edwards
# 1072      reg         lvl    allpub    inside          3      edwards
# 1123      reg         lvl    allpub    inside          3      edwards
# 1151      reg         lvl    allpub    inside          3      edwards
# 1185      reg         lvl    allpub    inside          3      edwards
# 1257      reg         lvl    allpub    corner          3      edwards
# 1294      reg         lvl    allpub    inside          3      edwards
# 1377      reg         lvl    allpub    inside          3      edwards
# 1452      reg         lvl    allpub    inside          3      edwards
# 1179      reg         lvl    allpub    corner          3      edwards
# 1459      reg         lvl    allpub    inside          3      edwards
# 607       reg         bnk    allpub    inside          2      edwards
# 418       reg         lvl    allpub    inside          3      edwards
# 395       reg         lvl    allpub    inside          3      edwards
# 390       reg         lvl    allpub    inside          3      edwards
# 502       reg         lvl    allpub    corner          3      edwards
# 535       reg         lvl    allpub    inside          3      edwards
# 386       reg         lvl    allpub       fr2          3      edwards
# 352       reg         lvl    allpub    inside          3      edwards
# 292       reg         lvl    allpub    inside          3      edwards
# 210       reg         lvl    allpub    inside          3      edwards
# 562       reg         lvl    allpub    inside          3      edwards
# 410       reg         lvl    allpub    inside          3      edwards
# 638       reg         lvl    allpub    inside          3      edwards
# 182       reg         lvl    allpub    inside          3      edwards
# 165       reg         lvl    allpub    inside          3      edwards
# 659       reg         lvl    allpub    corner          3      edwards
# 117       reg         lvl    allpub    corner          3      edwards
# 697       ir1         lvl    allpub    inside          3      edwards
# 98        reg         lvl    allpub    corner          3      edwards
# 1314      reg         lvl    allpub    inside          3      edwards
# 1319      reg         bnk    allpub    inside          3      edwards
# 200       reg         lvl    allpub    corner          3      edwards
# 1332      reg         lvl    allpub    inside          2      edwards
# 308       ir1         lvl    allpub    inside          3      edwards
# 1212      reg         lvl    allpub    inside          3      edwards
# 1448      reg         lvl    allpub    inside          3      edwards
# 97        reg         hls    allpub    inside          3      edwards
# 441       reg         lvl    allpub    inside          3      edwards
# 1144      reg         lvl    allpub    inside          3      edwards
# 1020      reg         lvl    allpub    inside          3      edwards
# 771       reg         lvl    allpub    inside          3      edwards
# 723       reg         lvl    allpub    inside          3      edwards
# 663       reg         lvl    allpub    inside          3      edwards
# 651       reg         lvl    allpub    inside          3      edwards
# 917       reg         lvl    allpub    inside          3      edwards
# 942       ir1         lvl    allpub    inside          3      edwards
# 749       reg         lvl    allpub    inside          3      edwards
# 978       reg         bnk    allpub    inside          2      edwards
# 1035      ir1         lvl    allpub   culdsac          3      edwards
# 1049      reg         low    allpub    inside          3      edwards
# 553       reg         lvl    allpub    inside          3      edwards
# 528       ir1         lvl    allpub    inside          3      edwards
# 1122      ir1         lvl    allpub    corner          3      edwards
# 39        reg         lvl    allpub    inside          3      edwards
# 1000      reg         lvl    allpub    corner          3      edwards
# 620       reg         lvl    allpub    inside          3      edwards
# 1326      reg         bnk    allpub    inside          2      edwards
# 1045      ir1         lvl    allpub   culdsac          3      edwards
# 1380      reg         lvl    allpub    inside          3      edwards
# 375       ir1         low    allpub    inside          1      edwards
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 523        posn       posn     1fam     2story           10            5
# 1298      feedr       norm     1fam     2story           10            5
# 724        norm       norm     1fam     1story            9            5
# 362        norm       norm     1fam     sfoyer            7            5
# 193        norm       norm    twnhs     2story            7            5
# 1254       norm       norm     1fam     2story            7            5
# 1088       norm       norm    twnhs     2story            7            5
# 1304       norm       norm   twnhse     2story            7            5
# 387        norm       norm     1fam       slvl            6            6
# 1168       norm       norm     1fam     2story            6            7
# 772        norm       norm     1fam       slvl            6            5
# 563        norm       norm     1fam     1.5fin            6            7
# 439        norm       norm     1fam     1.5fin            6            8
# 445        norm       norm     1fam     1story            6            5
# 472        norm       norm   twnhse       slvl            6            5
# 1073       norm       norm     1fam     2story            6            6
# 954        norm       norm   duplex     sfoyer            6            5
# 647        norm       norm     1fam     1story            6            5
# 1273       norm       norm     1fam       slvl            6            7
# 582        norm       norm   duplex     sfoyer            6            5
# 110        norm       norm     1fam     1.5fin            6            4
# 1297       norm       norm   twnhse     sfoyer            6            5
# 269        norm       norm     1fam     1story            6            7
# 239        norm       norm     1fam     1.5fin            6            4
# 211        norm       norm     1fam     1story            6            5
# 671      artery       norm     1fam     2story            6            6
# 175        norm       norm     1fam     1story            6            7
# 1384       norm       norm     1fam     1.5fin            6            5
# 155      artery       norm     1fam     1.5fin            6            5
# 145        norm       norm    twnhs     2story            6            5
# 1423       norm       norm     1fam       slvl            6            7
# 985        norm       norm   2fmcon     1story            5            5
# 814        norm       norm     1fam     1.5fin            5            7
# 839        norm       norm     1fam     1.5fin            5            6
# 880        norm       norm     1fam     1story            5            5
# 887        norm       norm     1fam     1.5fin            5            7
# 921       feedr       norm   duplex     1.5fin            5            7
# 738        norm       norm   duplex     1story            5            5
# 1011       norm       norm   duplex     1story            5            5
# 1053       norm       norm     1fam     1story            5            6
# 1072     artery       norm     1fam     1.5fin            5            3
# 1123       norm       norm     1fam     1story            5            9
# 1151       norm       norm     1fam     1story            5            4
# 1185       norm       norm     1fam     1.5fin            5            7
# 1257      feedr       norm     1fam     1story            5            8
# 1294       norm       norm     1fam     1story            5            7
# 1377       norm       norm     1fam     1.5fin            5            5
# 1452       norm       norm   twnhse       slvl            5            5
# 1179       norm       norm     1fam     1story            5            5
# 1459       norm       norm     1fam     1story            5            6
# 607        norm       norm     1fam     2story            5            8
# 418        norm       norm     1fam     1.5fin            5            6
# 395        norm       norm     1fam     1story            5            6
# 390        norm       norm     1fam     1.5fin            5            8
# 502       feedr       norm     1fam     1story            5            7
# 535        norm       norm   2fmcon     2story            5            7
# 386       feedr       norm     1fam     1.5fin            5            3
# 352      artery       norm     1fam     1.5fin            5            6
# 292        norm       norm     1fam     1.5fin            5            4
# 210        norm       norm     1fam     1story            5            6
# 562        norm       norm     1fam     1story            5            6
# 410        norm       norm     1fam     1story            5            3
# 638       feedr       norm     1fam     1story            5            7
# 182      artery       norm     1fam     1story            5            6
# 165        norm       norm   2fmcon     1.5fin            5            7
# 659        norm       norm     1fam     1story            5            7
# 117        norm       norm     1fam     1story            5            5
# 697        norm       norm     1fam     1story            5            7
# 98         norm       norm     1fam     1story            5            5
# 1314       norm       norm     1fam     1story            4            6
# 1319       norm       norm     1fam     1story            4            5
# 200        norm       norm     1fam     1story            4            5
# 1332       norm       norm     1fam     1story            4            6
# 308        norm       norm     1fam     1story            4            5
# 1212       norm       norm     1fam     1story            4            6
# 1448       norm       norm     1fam     2story            4            7
# 97         norm       norm     1fam     1story            4            5
# 441        norm       norm   duplex     1story            4            4
# 1144       norm       norm   2fmcon     1.5fin            4            4
# 1020       norm       norm     1fam     1story            4            5
# 771        norm       norm     1fam     1story            4            5
# 723        norm       norm     1fam     1.5fin            4            6
# 663        norm       norm     1fam     sfoyer            4            5
# 651      artery       norm     1fam     2story            4            5
# 917        norm       norm     1fam     1story            4            6
# 942        norm       norm   duplex     1story            4            3
# 749        norm       norm     1fam     1.5fin            4            3
# 978        norm       norm     1fam     1story            4            5
# 1035       norm       norm     1fam     1story            4            3
# 1049       norm       norm     1fam     1story            4            7
# 553       feedr       norm     1fam     1story            4            5
# 528        norm       norm     1fam     1story            4            7
# 1122       norm       norm     1fam     1story            4            3
# 39         norm       norm   duplex     1story            4            5
# 1000       norm       norm     1fam     1story            3            3
# 620        norm       norm     1fam     1story            3            3
# 1326       norm       norm     1fam     1story            3            6
# 1045       norm       norm     1fam     1story            3            5
# 1380       norm       norm     1fam     1story            3            3
# 375        norm       norm     1fam     1story            1            1
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 523        2007          2008       hip  compshg     cemntbd     cmentbd
# 1298       2008          2008       hip  clytile      stucco      stucco
# 724        2007          2008       hip  compshg     cemntbd     cmentbd
# 362        2003          2003     gable  compshg     hdboard     hdboard
# 193        2004          2004     gable  compshg     vinylsd     vinylsd
# 1254       2003          2004     gable  compshg     vinylsd     vinylsd
# 1088       2004          2004     gable  compshg     vinylsd     vinylsd
# 1304       2004          2004     gable  compshg     vinylsd     vinylsd
# 387        1976          1976       hip  compshg     metalsd     metalsd
# 1168       1935          1986       hip  compshg      stucco      stucco
# 772        1976          1976     gable  compshg     plywood     plywood
# 563        1918          1950     gable  compshg     wd sdng     wd sdng
# 439        1920          2000     gable  compshg     wd sdng     wd sdng
# 445        1956          1956       hip  compshg     wd sdng     wd sdng
# 472        2005          2005     gable  compshg     vinylsd     vinylsd
# 1073       1977          1977       hip  compshg     hdboard     plywood
# 954        1975          1975      flat  tar&grv     wdshing     plywood
# 647        1953          1953       hip  compshg     wd sdng     wd sdng
# 1273       1959          2006     gable  compshg     plywood     plywood
# 582        1990          1990     gable  compshg     hdboard     hdboard
# 110        1954          1972     gable  compshg     wd sdng     wd sdng
# 1297       2005          2006     gable  compshg     vinylsd     vinylsd
# 269        1976          1976       hip  compshg     hdboard     hdboard
# 239        1945          1950     gable  compshg     vinylsd     vinylsd
# 211        2009          2009     gable  compshg     vinylsd     vinylsd
# 671        1925          1950   gambrel  compshg     wd sdng     wd sdng
# 175        1950          2001     gable  compshg     wdshing     wd shng
# 1384       1939          1950     gable  compshg     wdshing     wd shng
# 155        1924          1950     gable  compshg     wd sdng     wd sdng
# 145        2004          2006     gable  compshg     vinylsd     vinylsd
# 1423       1966          1966      flat  tar&grv     plywood     plywood
# 985        1950          1950     gable  compshg     metalsd     metalsd
# 814        1918          1950     gable  compshg      stucco      stucco
# 839        1946          1995     gable  compshg     metalsd     metalsd
# 880        2005          2006     gable  compshg     vinylsd     vinylsd
# 887        1955          1955     gable  compshg     metalsd     metalsd
# 921        1900          2003     gable  compshg     metalsd     metalsd
# 738        1987          1988     gable  compshg     plywood     plywood
# 1011       1965          1965       hip  compshg     asphshn     asphshn
# 1053       1957          2002       hip  compshg     hdboard     hdboard
# 1072       1948          1950     gable  compshg     metalsd     metalsd
# 1123       1947          2008       hip  compshg     vinylsd     vinylsd
# 1151       1959          1959     gable  compshg     hdboard     plywood
# 1185       1924          1950     gable  compshg     asbshng     asbshng
# 1257       1922          1950     gable  compshg     wd sdng     wd sdng
# 1294       1955          1990       hip  compshg     wdshing     plywood
# 1377       1941          1960     gable  compshg     wd sdng     wd sdng
# 1452       2005          2005     gable  compshg     vinylsd     vinylsd
# 1179       1954          1954     gable  compshg     wd sdng     wd sdng
# 1459       1965          1965     gable  compshg     hdboard     hdboard
# 607        1948          2002     gable  compshg     metalsd     metalsd
# 418        1940          1950     gable  compshg     metalsd     metalsd
# 395        1956          1956     gable  compshg     wd sdng     wd sdng
# 390        1900          1950     gable  compshg     metalsd     metalsd
# 502        1965          1965       hip  compshg     metalsd     metalsd
# 535        1910          1991     gable  compshg     metalsd     metalsd
# 386        1910          1996   gambrel  compshg     wd sdng     vinylsd
# 352        1941          1950     gable  compshg     vinylsd     vinylsd
# 292        1949          2008     gable  compshg     wd sdng     wd sdng
# 210        1925          1950     gable  compshg      stucco      stucco
# 562        1940          1969     gable  compshg     wdshing     wd shng
# 410        1958          1958     gable  compshg     brkcomm     brk cmn
# 638        1910          1950     gable  compshg     metalsd     wd sdng
# 182        1957          2006       hip  compshg     wd sdng     wd sdng
# 165        1940          1999     gable  compshg     wd sdng     wd sdng
# 659        1964          1999       hip  compshg     metalsd     metalsd
# 117        2006          2007     gable  compshg     vinylsd     vinylsd
# 697        1952          1952     gable  compshg     wd sdng     wd sdng
# 98         1920          1950     gable  compshg     wd sdng     wd sdng
# 1314       1954          1954       hip  compshg     wd sdng     wd sdng
# 1319       1954          1954       hip  compshg     wd sdng     wd sdng
# 200        2003          2004     gable  compshg     vinylsd     vinylsd
# 1332       1938          1958     gable  compshg     metalsd     metalsd
# 308        1940          1950     gable  compshg     vinylsd     vinylsd
# 1212       1941          1950       hip  compshg     metalsd     metalsd
# 1448       1910          2000     gable  compshg     metalsd     hdboard
# 97         1965          1965       hip  compshg     hdboard     hdboard
# 441        1955          1955     gable  compshg     vinylsd     vinylsd
# 1144       1941          1950     gable  compshg     metalsd     metalsd
# 1020       2005          2005     gable  compshg     vinylsd     vinylsd
# 771        1951          1951     gable  compshg     wd sdng     wd sdng
# 723        1954          1972     gable  compshg     metalsd     metalsd
# 663        1972          1972     gable  compshg     plywood     plywood
# 651        1940          1950     gable  compshg     metalsd     metalsd
# 917        1956          1956     gable  compshg     vinylsd     vinylsd
# 942        1977          1977     gable  compshg     metalsd     metalsd
# 749        1945          1950     gable  compshg     wdshing     wd shng
# 978        1954          1954     gable  compshg     metalsd     metalsd
# 1035       1957          1957     gable  compshg     wd sdng     wd sdng
# 1049       1946          2006     gable  compshg     metalsd     metalsd
# 553        1949          2003     gable  compshg     vinylsd     vinylsd
# 528        1920          2002     gable  compshg     wd sdng     wd sdng
# 1122       1956          1956     gable  compshg     asbshng     asbshng
# 39         1955          1955     gable  compshg     asbshng     plywood
# 1000       1952          1952      flat  tar&grv     brkcomm     brk cmn
# 620        1914          1950     gable  compshg      stucco      stucco
# 1326       1931          2006     gable  compshg     metalsd     metalsd
# 1045       1955          1955       hip  compshg     brkface     wd sdng
# 1380       1914          1950     gable  compshg      stucco      stucco
# 375        1922          1950     gable  compshg     wd sdng     wd sdng
#
#      MasVnrType  MasVnrArea  ExterQual  ExterCond Foundation  BsmtQual  \
# 523       stone         762          5          3      pconc         5
# 1298      stone         796          5          3      pconc         5
# 724       stone         340          5          3      pconc         5
# 362     brkface         500          4          3       slab         0
# 193       stone          50          4          3      pconc         4
# 1254      stone          92          4          3      pconc         4
# 1088      stone          50          4          3      pconc         4
# 1304      stone         117          4          3      pconc         4
# 387     brkface         255          3          3     cblock         3
# 1168    nothing           0          3          3     cblock         3
# 772     nothing           0          3          3     cblock         3
# 563     nothing           0          3          3     brktil         4
# 439     nothing           0          3          3     brktil         3
# 445     nothing           0          3          3     cblock         3
# 472     brkface          80          3          3      pconc         4
# 1073    brkface         140          3          3     cblock         3
# 954     brkface         250          3          3     cblock         4
# 647       stone         216          3          3     cblock         3
# 1273    brkface          84          3          3     cblock         3
# 582     brkface         104          3          4     cblock         4
# 110     nothing           0          3          3     cblock         3
# 1297    brkface          82          3          3      pconc         4
# 269     brkface         174          3          4     cblock         3
# 239     nothing           0          3          3     cblock         3
# 211     nothing           0          3          3      pconc         4
# 671     nothing           0          3          4     brktil         3
# 175     nothing           0          3          3     cblock         3
# 1384    nothing           0          3          3     brktil         3
# 155     nothing           0          3          3     brktil         3
# 145       stone          50          4          3      pconc         4
# 1423    nothing           0          4          4     cblock         4
# 985     nothing           0          3          3     cblock         3
# 814     nothing           0          3          3     brktil         3
# 839     nothing           0          3          3     cblock         3
# 880     nothing           0          3          3      pconc         5
# 887     nothing           0          3          4      pconc         3
# 921     nothing           0          3          3     cblock         3
# 738     nothing           0          3          3     cblock         4
# 1011    nothing           0          3          3     cblock         0
# 1053      stone         145          3          3     cblock         3
# 1072    nothing           0          3          3     cblock         2
# 1123    nothing           0          3          5     cblock         3
# 1151    brkface         132          3          3     cblock         3
# 1185    nothing           0          3          4     brktil         3
# 1257    nothing           0          3          3      pconc         2
# 1294    nothing           0          3          3     cblock         3
# 1377    nothing           0          3          3     cblock         3
# 1452    brkface          80          3          3      pconc         4
# 1179    nothing           0          3          3       slab         0
# 1459    nothing           0          4          3     cblock         3
# 607     nothing           0          3          4     cblock         3
# 418     nothing           0          3          3     brktil         3
# 395     nothing           0          3          3     cblock         3
# 390     nothing           0          3          3     brktil         3
# 502     nothing           0          3          3     cblock         3
# 535     nothing           0          3          3     cblock         4
# 386     nothing           0          3          2      pconc         3
# 352     nothing           0          3          3     cblock         3
# 292     nothing           0          3          3     cblock         3
# 210     nothing           0          3          3     cblock         3
# 562     nothing           0          3          3     cblock         3
# 410     nothing           0          3          2     cblock         3
# 638     nothing           0          3          3     cblock         2
# 182     brkface          98          3          3      pconc         0
# 165     nothing           0          3          4     brktil         3
# 659     nothing           0          3          4      pconc         3
# 117     nothing           0          3          3      pconc         4
# 697     nothing           0          3          3      pconc         5
# 98      nothing           0          3          3     brktil         3
# 1314    nothing           0          3          3     cblock         3
# 1319    brkface         132          3          3      pconc         3
# 200     nothing           0          3          3      pconc         4
# 1332    nothing           0          3          3     cblock         3
# 308     nothing           0          3          3     cblock         3
# 1212    nothing           0          3          3     cblock         3
# 1448    nothing           0          3          3     cblock         2
# 97      brkface          48          3          3     cblock         3
# 441     brkface         270          3          3     cblock         3
# 1144    nothing           0          3          2     brktil         4
# 1020    nothing           0          3          3      pconc         4
# 771     nothing           0          3          3     cblock         2
# 723     nothing           0          3          3      pconc         3
# 663     nothing           0          3          3     cblock         4
# 651     nothing           0          3          3     cblock         3
# 917     nothing           0          3          3     cblock         3
# 942     nothing           0          3          3      pconc         4
# 749     nothing           0          3          3       slab         0
# 978     nothing           0          3          3     cblock         3
# 1035    nothing           0          3          4       slab         0
# 1049    nothing           0          3          3     cblock         0
# 553     nothing           0          3          3     cblock         0
# 528     nothing           0          3          3     brktil         3
# 1122    nothing           0          3          3     cblock         3
# 39      nothing           0          3          3      pconc         0
# 1000    nothing           0          3          3       slab         0
# 620     nothing           0          3          3     brktil         3
# 1326    nothing           0          3          3     brktil         3
# 1045    nothing           0          3          3       slab         0
# 1380    nothing           0          3          2     brktil         3
# 375     nothing           0          2          2     brktil         2
#
#      BsmtCond BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 523        ta           gd             6        2260             1
# 1298       ta           gd             6        5644             1
# 724        ta           no             6        1234             1
# 362   nothing      nothing             0           0             0
# 193        ta           no             1           0             1
# 1254       ta           no             1           0             1
# 1088       ta           no             1           0             1
# 1304       ta           no             1           0             1
# 387        ta           av             5         631             1
# 1168       ta           no             3         626             1
# 772        ta           av             5         422             4
# 563        ta           mn             1           0             1
# 439        fa           mn             1           0             1
# 445        ta           no             1           0             1
# 472        ta           gd             6         459             1
# 1073       ta           no             4         535             1
# 954        gd           gd             6         945             1
# 647        ta           mn             3         500             1
# 1273       ta           av             5         719             1
# 582        ta           av             6         816             1
# 110        fa           no             3         444             1
# 1297       ta           gd             6         547             1
# 269        gd           no             4         751             1
# 239        fa           no             2          94             1
# 211        ta           mn             6          36             1
# 671        ta           no             4         551             1
# 175        gd           av             5         477             1
# 1384       ta           mn             3         204             1
# 155        ta           no             1           0             1
# 145        ta           no             1           0             1
# 1423       ta           av             1           0             1
# 985        ta           no             5        1040             1
# 814        ta           no             1           0             1
# 839        ta           no             4         352             1
# 880        gd           no             5         980             1
# 887        ta           no             1           0             1
# 921        ta           no             5        1084             1
# 738        gd           gd             6        1200             1
# 1011  nothing      nothing             0           0             0
# 1053       ta           av             3         383             1
# 1072       fa           mn             1           0             1
# 1123       ta           no             1           0             1
# 1151       ta           no             4         176             1
# 1185       ta           no             4         392             1
# 1257       ta           no             1           0             1
# 1294       ta           no             3         167             1
# 1377       ta           no             2         408             4
# 1452       ta           gd             6         547             1
# 1179  nothing      nothing             0           0             0
# 1459       ta           no             4         830             2
# 607        gd           no             6         603             1
# 418        ta           no             5         312             1
# 395        ta           av             4         739             1
# 390        gd           no             3         241             4
# 502        ta           no             5         698             6
# 535        ta           gd             6         969             1
# 386        ta           no             1           0             1
# 352        fa           mn             2         236             3
# 292        ta           no             2         292             1
# 210        ta           no             3         468             1
# 562        ta           no             4         290             1
# 410        fa           no             1           0             1
# 638        ta           no             1           0             1
# 182   nothing      nothing             0           0             0
# 165        ta           no             5         351             3
# 659        ta           no             4         637             1
# 117        ta           no             1           0             1
# 697        gd           mn             2         210             5
# 98         ta           no             5         108             1
# 1314       ta           no             3         732             1
# 1319       ta           no             5         492             1
# 200        ta           no             1           0             1
# 1332       ta           mn             5         690             1
# 308        ta           no             4         262             1
# 1212       ta           no             3         344             1
# 1448       ta           no             1           0             1
# 97         ta           no             3         520             1
# 441        ta           no             5         133             1
# 1144       ta           no             4         348             1
# 1020       ta           no             6        1024             1
# 771        fa           no             2         836             1
# 723        ta           no             1           0             1
# 663        ta           av             4         920             3
# 651        ta           mn             1           0             1
# 917        ta           no             5        1059             1
# 942        ta           gd             6        1440             1
# 749   nothing      nothing             0           0             0
# 978        ta           no             2         552             1
# 1035  nothing      nothing             0           0             0
# 1049  nothing      nothing             0           0             0
# 553   nothing      nothing             0           0             0
# 528        ta           mn             5         348             1
# 1122       ta           no             1           0             1
# 39    nothing      nothing             0           0             0
# 1000  nothing      nothing             0           0             0
# 620        ta           no             4          41             1
# 1326       ta           no             3         544             1
# 1045  nothing      nothing             0           0             0
# 1380       fa           no             3         203             1
# 375        po           gd             4         350             1
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  HeatingQC CentralAir  \
# 523            0        878         3138    gasa          5          y
# 1298           0        466         6110    gasa          5          y
# 724            0        464         1698    gasa          5          y
# 362            0          0            0    gasa          5          y
# 193            0        970          970    gasa          5          y
# 1254           0        746          746    gasa          5          y
# 1088           0        970          970    gasa          5          y
# 1304           0        976          976    gasa          5          y
# 387            0        410         1041    gasa          5          y
# 1168           0        501         1127    gasa          5          y
# 772          127        480         1029    gasa          3          y
# 563            0       1163         1163    gasa          5          y
# 439            0        684          684    gasa          4          y
# 445            0       1436         1436    gasa          2          y
# 472            0         88          547    gasa          5          y
# 1073           0        155          690    gasa          3          y
# 954            0          0          945    gasa          3          y
# 647            0        594         1094    gasa          5          y
# 1273           0        300         1019    gasa          4          y
# 582            0          0          816    gasa          3          y
# 110            0        550          994    gasa          4          y
# 1297           0          0          547    gasa          4          y
# 269            0        392         1143    gasa          3          y
# 239            0        641          735    gasa          3          y
# 211            0       1176         1212    gasa          5          y
# 671            0        121          672    gasa          3          n
# 175            0        725         1202    gasa          3          y
# 1384           0        356          560    gasa          3          y
# 155            0        572          572    grav          2          n
# 145            0        970          970    gasa          5          y
# 1423           0        697          697    gasa          3          y
# 985            0        124         1164    gasw          3          n
# 814            0        686          686    gasw          4          y
# 839            0        416          768    gasa          5          y
# 880            0        110         1090    gasa          4          y
# 887            0        816          816    gasa          3          y
# 921            0        188         1272    gasa          4          y
# 738            0          0         1200    gasa          3          y
# 1011           0          0            0    gasa          3          n
# 1053           0        833         1216    gasa          5          y
# 1072           0        810          810    gasa          2          y
# 1123           0        698          698    gasa          5          y
# 1151           0       1290         1466    gasa          3          y
# 1185           0        392          784    gasa          4          y
# ...
# 663             180          0            0         0       0    mnprv
# 651               0          0            0         0       0    mnprv
# 917               0          0            0         0       0  nothing
# 942               0          0            0         0       0  nothing
# 749             185          0            0         0       0  nothing
# 978               0          0            0         0       0  nothing
# 1035              0          0            0         0       0  nothing
# 1049              0          0            0         0       0  nothing
# 553               0          0            0         0       0    mnprv
# 528             144          0            0         0       0  nothing
# 1122              0          0          160         0       0    mnprv
# 39                0          0            0         0       0  nothing
# 1000              0          0            0         0       0  nothing
# 620             100          0            0         0       0  nothing
# 1326            286          0            0         0       0  nothing
# 1045              0          0            0         0       0  nothing
# 1380             96          0            0         0       0  nothing
# 375               0          0            0         0       0  nothing
#
#      MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  \
# 523      nothing        0      10    2007      new       partial     184750
# 1298     nothing        0       1    2008      new       partial     160000
# 724      nothing        0       2    2009       wd        normal     320000
# 362      nothing        0       7    2009    conld        normal     198500
# 193      nothing        0       5    2006       wd        normal     130000
# 1254     nothing        0       7    2008       wd        normal     165400
# 1088     nothing        0       4    2006       wd        normal     137500
# 1304     nothing        0       4    2006       wd        normal     130000
# 387      nothing        0      10    2009       wd       abnorml     125000
# 1168     nothing        0       7    2008       wd        normal     235000
# 772      nothing        0       3    2010       wd       abnorml     107000
# 563      nothing        0       7    2008       wd        normal     185000
# 439         shed      800       8    2009    conli        normal     110000
# 445      nothing        0      11    2009      cod        normal     127500
# 472      nothing        0       6    2008       wd        normal     148000
# 1073     nothing        0       7    2009       wd        normal     159500
# 954      nothing        0      10    2006       wd       adjland     127500
# 647      nothing        0       6    2008       wd        normal     155000
# 1273     nothing        0       5    2008       wd        normal     177000
# 582      nothing        0       5    2007       wd        normal     118500
# 110      nothing        0      10    2006       wd        normal     136900
# 1297     nothing        0       6    2006      new       partial     140000
# 269      nothing        0       5    2007       wd        normal     148000
# 239      nothing        0       4    2010       wd        normal     113000
# 211      nothing        0       3    2010       wd        normal     186000
# 671      nothing        0       7    2009       wd        normal     103600
# 175      nothing        0       6    2007       wd        normal     243000
# 1384     nothing        0      10    2009       wd        normal     105000
# 155      nothing        0       4    2008       wd        normal      79000
# 145      nothing        0       4    2006       wd        normal     130000
# 1423     nothing        0       8    2006       wd        alloca     274970
# 985      nothing        0       8    2008    conld        normal     125000
# 814      nothing        0       7    2006       wd        normal     116000
# 839      nothing        0       5    2008       wd        normal     130500
# 880      nothing        0       6    2007       wd        normal     157000
# 887      nothing        0       4    2008       wd        normal     135500
# 921      nothing        0       9    2008       wd        normal     145900
# 738      nothing        0       3    2009       wd        alloca     179000
# 1011     nothing        0       5    2010       wd        normal     100000
# 1053     nothing        0       5    2010       wd        normal     144500
# 1072     nothing        0       8    2006       wd        normal      91500
# 1123     nothing        0       6    2009       wd        normal     118000
# 1151     nothing        0      11    2006       wd        normal     149900
# 1185     nothing        0       3    2006       wd        normal     104900
# 1257     nothing        0       7    2009       wd        normal      99900
# 1294     nothing        0       4    2006       wd        normal     115000
# 1377     nothing        0       7    2009       wd        normal     117000
# 1452     nothing        0       5    2006       wd        normal     145000
# 1179     nothing        0       4    2006       wd        normal      93000
# 1459     nothing        0       6    2008       wd        normal     147500
# 607      nothing        0       8    2006       wd        normal     225000
# 418      nothing        0       4    2007       wd       adjland     126000
# 395      nothing        0       6    2010       wd        normal     129000
# 390      nothing        0       4    2008       wd        normal     119000
# 502         shed      400       4    2007       wd        normal     140000
# 535      nothing        0       1    2008       wd        normal     107500
# 386      nothing        0       5    2006       wd       adjland      81000
# 352      nothing        0       3    2008    conlw        normal      95000
# 292      nothing        0       1    2009       wd        normal     131000
# 210      nothing        0       4    2008       wd        normal      98000
# 562      nothing        0       7    2008       wd        normal     108000
# 410      nothing        0       6    2009      cod       abnorml      60000
# 638      nothing        0       5    2008       wd        normal      85000
# 182      nothing        0       6    2007       wd        normal     120000
# 165      nothing        0       9    2008       wd        normal     127500
# 659      nothing        0       3    2009       wd        normal     167000
# 117      nothing        0       4    2007      new       partial     155000
# 697      nothing        0       9    2006       wd        normal     123500
# 98          shed      400       5    2010      cod       abnorml      83000
# 1314     nothing        0      10    2007       wd        normal     119000
# 1319     nothing        0       2    2007       wd        normal     111000
# 200      nothing        0       3    2010       wd        normal     140000
# 1332     nothing        0       5    2009       wd        normal     100000
# 308      nothing        0       3    2009       wd        normal      82500
# 1212     nothing        0       8    2009       wd        normal     113000
# 1448     nothing        0       5    2007       wd        normal     112000
# 97       nothing        0       5    2007       wd        normal      94750
# 441      nothing        0       9    2008       wd        normal     118000
# 1144     nothing        0       7    2010       wd        normal      80000
# 1020     nothing        0       6    2008       wd        normal     176000
# 771      nothing        0       4    2006      cod        normal     102000
# 723      nothing        0       5    2008       wd        normal     135000
# 663      nothing        0       4    2008       wd        normal     137500
# 651      nothing        0      10    2009       wd        normal     108000
# 917      nothing        0       4    2009       wd        normal     135000
# 942      nothing        0       8    2007      oth       abnorml     150000
# 749      nothing        0       4    2009       wd        normal      98000
# 978      nothing        0       5    2007       wd       abnorml     110000
# 1035     nothing        0       1    2009       wd        normal      84000
# 1049     nothing        0       4    2010       wd       abnorml      84900
# 553      nothing        0       5    2009       wd        normal     108000
# 528      nothing        0       7    2007       wd        normal      86000
# 1122     nothing        0      10    2009      cod       abnorml     112000
# 39       nothing        0       6    2008       wd       adjland      82000
# 1000     nothing        0       7    2009       wd        normal      82000
# 620      nothing        0       9    2008       wd        normal      67000
# 1326     nothing        0       5    2007       wd        normal      79000
# 1045     nothing        0       6    2009       wd        normal     139600
# 1380     nothing        0       6    2010       wd        normal      58500
# 375      nothing        0       3    2009       wd        normal      61000
#
#       decade_YearBuilt  decade_YearRemodAdd  decade_GarageYrBlt
# 523                 10                   10                  10
# 1298                10                   10                  10
# 724                 10                   10                  10
# 362                 10                   10                  10
# 193                 10                   10                  10
# 1254                10                   10                  10
# 1088                10                   10                  10
# 1304                10                   10                  10
# 387                  7                    7                   7
# 1168                 3                    8                   3
# 772                  7                    7                   7
# 563                  1                    5                   5
# 439                  2                   10                  10
# 445                  5                    5                   5
# 472                 10                   10                  10
# 1073                 7                    7                   7
# 954                  7                    7                   7
# 647                  5                    5                   5
# 1273                 5                   10                   5
# 582                  9                    9                   9
# 110                  5                    7                   5
# 1297                10                   10                  10
# 269                  7                    7                   8
# 239                  4                    5                   4
# 211                 10                   10                  10
# 671                  2                    5                   3
# 175                  5                   10                   5
# 1384                 3                    5                   3
# 155                  2                    5                   2
# 145                 10                   10                  10
# 1423                 6                    6                   6
# 985                  5                    5                   5
# 814                  1                    5                   5
# 839                  4                    9                   4
# 880                 10                   10                  10
# 887                  5                    5                   5
# 921                  1                   10                   1
# 738                  8                    8                   8
# 1011                 6                    6                   6
# 1053                 5                   10                   5
# 1072                 4                    5                   5
# 1123                 4                   10                   4
# 1151                 5                    5                   5
# 1185                 2                    5                   6
# 1257                 2                    5                   2
# 1294                 5                    9                   5
# 1377                 4                    6                   7
# 1452                10                   10                  10
# 1179                 5                    5                   5
# 1459                 6                    6                   6
# 607                  4                   10                   4
# 418                  4                    5                   4
# 395                  5                    5                   5
# 390                  1                    5                   7
# 502                  6                    6                   6
# 535                  1                    9                   1
# 386                  1                    9                   1
# 352                  4                    5                   4
# 292                  4                   10                   4
# 210                  2                    5                   2
# 562                  4                    6                   4
# 410                  5                    5                   5
# 638                  1                    5                   1
# 182                  5                   10                   5
# 165                  4                    9                   4
# 659                  6                    9                   6
# 117                 10                   10                  10
# 697                  5                    5                   5
# 98                   2                    5                   2
# 1314                 5                    5                   5
# 1319                 5                    5                   5
# 200                 10                   10                  10
# 1332                 3                    5                   5
# 308                  4                    5                   6
# 1212                 4                    5                   4
# 1448                 1                   10                   5
# 97                   6                    6                   6
# 441                  5                    5                   5
# 1144                 4                    5                   4
# 1020                10                   10                  10
# 771                  5                    5                   5
# 723                  5                    7                   5
# 663                  7                    7                   7
# 651                  4                    5                   4
# 917                  5                    5                   5
# 942                  7                    7                   7
# 749                  4                    5                   4
# 978                  5                    5                   9
# 1035                 5                    5                   5
# 1049                 4                   10                   4
# 553                  4                   10                  10
# 528                  2                   10                   2
# 1122                 5                    5                   5
# 39                   5                    5                   5
# 1000                 5                    5                   5
# 620                  1                    5                   1
# 1326                 3                   10                   3
# 1045                 5                    5                   5
# 1380                 1                    5                   3
# 375                  2                    5                   2

# %%
data.groupby('YrSold')['SalePrice'].median()
# Out:
# YrSold
# 2006    163995
# 2007    167000
# 2008    164000
# 2009    162000
# 2010    155000
# Name: SalePrice, dtype: int64

# %%
traino_saleprice_c = data[data.SalePrice.apply(lambda x: np.abs(x-data.SalePrice.mean())/data.SalePrice.std() < 2)] # 95% of data

# %%
traino_saleprice_c
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       rl           65     8450   pave  nothing
# 1        2          20       rl           80     9600   pave  nothing
# 2        3          60       rl           68    11250   pave  nothing
# 3        4          70       rl           60     9550   pave  nothing
# 4        5          60       rl           84    14260   pave  nothing
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       rl           62     7917   pave  nothing
# 1456  1457          20       rl           85    13175   pave  nothing
# 1457  1458          70       rl           66     9042   pave  nothing
# 1458  1459          20       rl           68     9717   pave  nothing
# 1459  1460          20       rl           75     9937   pave  nothing
#
#      LotShape LandContour Utilities LotConfig  LandSlope Neighborhood  \
# 0         reg         lvl    allpub    inside          3      collgcr
# 1         reg         lvl    allpub       fr2          3      veenker
# 2         ir1         lvl    allpub    inside          3      collgcr
# 3         ir1         lvl    allpub    corner          3      crawfor
# 4         ir1         lvl    allpub       fr2          3      noridge
# ...       ...         ...       ...       ...        ...          ...
# 1455      reg         lvl    allpub    inside          3      gilbert
# 1456      reg         lvl    allpub    inside          3       nwames
# 1457      reg         lvl    allpub    inside          3      crawfor
# 1458      reg         lvl    allpub    inside          3        names
# 1459      reg         lvl    allpub    inside          3      edwards
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0          norm       norm     1fam     2story            7            5
# 1         feedr       norm     1fam     1story            6            8
# 2          norm       norm     1fam     2story            7            5
# 3          norm       norm     1fam     2story            7            5
# 4          norm       norm     1fam     2story            8            5
# ...         ...        ...      ...        ...          ...          ...
# 1455       norm       norm     1fam     2story            6            5
# 1456       norm       norm     1fam     1story            6            6
# 1457       norm       norm     1fam     2story            7            9
# 1458       norm       norm     1fam     1story            5            6
# 1459       norm       norm     1fam     1story            5            6
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0          2003          2003     gable  compshg     vinylsd     vinylsd
# 1          1976          1976     gable  compshg     metalsd     metalsd
# 2          2001          2002     gable  compshg     vinylsd     vinylsd
# 3          1915          1970     gable  compshg     wd sdng     wd shng
# 4          2000          2000     gable  compshg     vinylsd     vinylsd
# ...         ...           ...       ...      ...         ...         ...
# 1455       1999          2000     gable  compshg     vinylsd     vinylsd
# 1456       1978          1988     gable  compshg     plywood     plywood
# 1457       1941          2006     gable  compshg     cemntbd     cmentbd
# 1458       1950          1996       hip  compshg     metalsd     metalsd
# 1459       1965          1965     gable  compshg     hdboard     hdboard
#
#      MasVnrType  MasVnrArea  ExterQual  ExterCond Foundation  BsmtQual  \
# 0       brkface         196          4          3      pconc         4
# 1       nothing           0          3          3     cblock         4
# 2       brkface         162          4          3      pconc         4
# 3       nothing           0          3          3     brktil         3
# 4       brkface         350          4          3      pconc         4
# ...         ...         ...        ...        ...        ...       ...
# 1455    nothing           0          3          3      pconc         4
# 1456      stone         119          3          3     cblock         4
# 1457    nothing           0          5          4      stone         3
# 1458    nothing           0          3          3     cblock         3
# 1459    nothing           0          4          3     cblock         3
#
#      BsmtCond BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 0          ta           no             6         706             1
# 1          ta           gd             5         978             1
# 2          ta           mn             6         486             1
# 3          gd           no             5         216             1
# 4          ta           av             6         655             1
# ...       ...          ...           ...         ...           ...
# 1455       ta           no             1           0             1
# 1456       ta           no             5         790             3
# 1457       gd           no             6         275             1
# 1458       ta           mn             6          49             3
# 1459       ta           no             4         830             2
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  HeatingQC CentralAir  \
# 0              0        150          856    gasa          5          y
# 1              0        284         1262    gasa          5          y
# 2              0        434          920    gasa          5          y
# 3              0        540          756    gasa          4          y
# 4              0        490         1145    gasa          5          y
# ...          ...        ...          ...     ...        ...        ...
# 1455           0        953          953    gasa          5          y
# 1456         163        589         1542    gasa          3          y
# 1457           0        877         1152    gasa          5          y
# 1458        1029          0         1078    gasa          4          y
# 1459         290        136         1256    gasa          4          y
#
#      Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0         sbrkr       856       854             0       1710             1
# 1         sbrkr      1262         0             0       1262             0
# 2         sbrkr       920       866             0       1786             1
# 3         sbrkr       961       756             0       1717             1
# 4         sbrkr      1145      1053             0       2198             1
# ...         ...       ...       ...           ...        ...           ...
# 1455      sbrkr       953       694             0       1647             0
# 1456      sbrkr      2073         0             0       2073             1
# 1457      sbrkr      1188      1152             0       2340             0
# 1458      fusea      1078         0             0       1078             1
# 1459      sbrkr      1256         0             0       1256             1
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0                0         2         1             3             1
# 1                1         2         0             3             1
# 2                0         2         1             3             1
# 3                0         1         0             3             1
# 4                0         2         1             4             1
# ...            ...       ...       ...           ...           ...
# 1455             0         2         1             3             1
# 1456             0         2         0             3             1
# 1457             0         2         0             4             1
# 1458             0         1         0             2             1
# 1459             0         1         1             3             1
#
#      KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  \
# 0             gd             8           8           0            0
# 1             ta             6           8           1            3
# 2             gd             6           8           1            3
# 3             gd             7           8           1            4
# 4             gd             9           8           1            3
# ...          ...           ...         ...         ...          ...
# 1455          ta             7           8           1            3
# 1456          ta             7           7           2            3
# 1457          gd             9           8           2            4
# 1458          gd             5           8           0            0
# 1459          ta             6           8           0            0
#
#      GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 0        attchd         2003             2           2         548
# 1        attchd         1976             2           2         460
# 2        attchd         2001             2           2         608
# 3        detchd         1998             1           3         642
# 4        attchd         2000             2           3         836
# ...         ...          ...           ...         ...         ...
# 1455     attchd         1999             2           2         460
# 1456     attchd         1978             1           2         500
# 1457     attchd         1941             2           1         252
# 1458     attchd         1950             1           1         240
# 1459     attchd         1965             3           1         276
#
#       GarageQual  GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0              3           3          y           0           61
# 1              3           3          y         298            0
# 2              3           3          y           0           42
# 3              3           3          y           0           35
# 4              3           3          y         192           84
# ...          ...         ...        ...         ...          ...
# 1455           3           3          y           0           40
# 1456           3           3          y         349            0
# 1457           3           3          y           0           60
# 1458           3           3          y         366            0
# 1459           3           3          y         736           68
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC    Fence  \
# 0                 0          0            0         0       0  nothing
# 1                 0          0            0         0       0  nothing
# 2                 0          0            0         0       0  nothing
# 3               272          0            0         0       0  nothing
# 4                 0          0            0         0       0  nothing
# ...             ...        ...          ...       ...     ...      ...
# 1455              0          0            0         0       0  nothing
# 1456              0          0            0         0       0    mnprv
# 1457              0          0            0         0       0    gdprv
# 1458            112          0            0         0       0  nothing
# 1459              0          0            0         0       0  nothing
#
#      MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  \
# 0        nothing        0       2    2008       wd        normal     208500
# 1        nothing        0       5    2007       wd        normal     181500
# 2        nothing        0       9    2008       wd        normal     223500
# 3        nothing        0       2    2006       wd       abnorml     140000
# 4        nothing        0      12    2008       wd        normal     250000
# ...          ...      ...     ...     ...      ...           ...        ...
# 1455     nothing        0       8    2007       wd        normal     175000
# 1456     nothing        0       2    2010       wd        normal     210000
# 1457        shed     2500       5    2010       wd        normal     266500
# 1458     nothing        0       4    2010       wd        normal     142125
# 1459     nothing        0       6    2008       wd        normal     147500
#
#       decade_YearBuilt  decade_YearRemodAdd  decade_GarageYrBlt
# 0                   10                   10                  10
# 1                    7                    7                   7
# 2                   10                   10                  10
# 3                    1                    7                   9
# 4                   10                   10                  10
# ...                ...                  ...                 ...
# 1455                 9                   10                   9
# 1456                 7                    8                   7
# 1457                 4                   10                   4
# 1458                 5                    9                   5
# 1459                 6                    6                   6
#
# [1397 rows x 84 columns]
